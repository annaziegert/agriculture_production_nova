# %%
from Class.my_class import Group22

# %% [markdown]
# ## Load data

# %%
agros_data = Group22('https://raw.githubusercontent.com/owid/owid-datasets/master/datasets/Agricultural%20total%20factor%20productivity%20(USDA)/Agricultural%20total%20factor%20productivity%20(USDA).csv', 'agr_data')
Group22.download_data(agros_data)
# Out:
# agr_data already exists
# (            Entity  Year       tfp    output    inputs  ag_land_index  \
#  0      Afghanistan  1961   65.0814   44.8285   68.8807        91.6812
#  1      Afghanistan  1962   64.0637   45.6182   71.2075        92.2016
#  2      Afghanistan  1963   61.6217   45.9729   74.6051        92.6352
#  3      Afghanistan  1964   65.1109   49.0775   75.3752        93.1816
#  4      Afghanistan  1965   63.8587   51.2121   80.1960        93.1990
#  ...            ...   ...       ...       ...       ...            ...
#  12177     Zimbabwe  2015  100.0000  100.0000  100.0000       100.0000
#  12178     Zimbabwe  2016   94.8110   98.1051  103.4744       103.8526
#  12179     Zimbabwe  2017  101.9830  104.9815  102.9402        99.6960
#  12180     Zimbabwe  2018  118.1959  121.0832  102.4428       102.8520
#  12181     Zimbabwe  2019  114.9524  114.2108   99.3549        92.5939
#
#         labor_index  capital_index  materials_index  output_quantity  ...  \
# ...

# %% [markdown]
# # Day 1 – Let's begin by telling a story

# %% [markdown]
# ## Gapminder (gapminder method)
#
# ### Analysis:
# The scatter plot below shows the relation between fertilizer and output quantity in 2019 between different countries. The size of the dots indicate the invested agricultural capital. In general, the output quantity increases exponentially with the fertilizer quantity. The graph also shows that the invested capital is naturally linked to used quantity of fertilizer. In short: **The more capital you invest, the more fertilizer you can buy, and ultimately, the higher the output is going to be. This means that fertilizer generally work quite well and is essential for agricultural productivity.**

# %%
Group22.__gapminder__(agros_data, 2019)

# %% [markdown]
# ## Plot output areas (__plot_output_area_chart__ method)
#
# ### Chosen countries: Norway, India, and Australia
#
# ### Analysis:
# The main differences between the countries **Norway, India, and Australia** is the difference in the quantity of crop, animal, and fish output. We intentionally chose those countries as we expected to see their respective strengths in different agricultural outputs of each country. As you can see **Norway mainly depends on fish, India on crops and Australia on animals.**
#
# Nearly all outputs of the chosen countries have a quite linear growth, except for Norway's fishing output, which has been increasing more drastically since the 90s.

# %%
Group22.plot_output_area_chart(agros_data, country="Norway")

# %%
Group22.plot_output_area_chart(agros_data, country='India')

# %%
Group22.plot_output_area_chart(agros_data, country='Australia')

# %% [markdown]
# ## Compare output from countries (__compare_output_countries__ method)
#
# ### Analysis:
# While the total output of Norway and Australia stays rather stable during the years 1960 to 2019, India has seen a huge growth in total output.
# Also, the total output of India is higher in comparison to Australia and Norway as India is way more populated.

# %%
Group22.compare_output_countries(agros_data, ['Norway', 'India', 'Australia'])

# %% [markdown]
# ## Plot quantity correlation (__plot_quantity_correlation__ method)
#
# ### Analysis:
# As presented in the correlation matrix, most of the quantities have a high correlation (over 0.85). The high correlations can also be explained that countries try to spread their investments in agriculture equally and not only rely on a single pillar of production. The same holds true for countries that are less developed as they do not have the means to invest significantly in any agricultural sector.
#
# The lowest correlation is between pasture_quantity and fish_output_quantity (0.55), which can be explained which pasture being a land covered with grass for grazing animals, while fish live in the sea/ocean. The in comparison low correlation between fish_output_quantity and any other quantity-columns is due to the fact that most of the quantity columns are earth-related. Aditionally, the fishing sector is highly dependent on the geographical location of the respective country, which further lowers certain correlations.

# %%
Group22.plot_quantity_correlation(agros_data)

# %% [markdown]
# ## Global chart for output quantity over the years
#
# ### Analysis:
# Overall, you can see that the total output of the world continues to increase, especially since the early 2000s, where World Hunger started to be fought effectively. Until today, crops are still the main food source for humans, followed by animals. Fish can be seen as a small addition to the global food supply, that continues to rise in recent years.

# %%
Group22.plot_output_area_chart(agros_data)

# %% [markdown]
# # Day 2 – Finishing up

# %% [markdown]
# ## Gapminder for 1980 and 2019
#
# ### Analysis:
# Between 1980 and 2019, the total agricultural output of the world increased dramatically as shown in the two graphs below. This increase can be seen not only on a global scale but also on a country-by-country basis, with many nations experiencing significant growth in their agricultural sectors. Countries such as India and China, which have large populations and growing economies, saw particularly impressive growth in their agricultural output during this period. These increases can be attributed to a variety of factors, including technological advancements in farming practices, increased investment in the agricultural sector, and improved infrastructure for transporting agricultural products. Overall, this growth in agricultural output has helped to ensure that the world's growing population has access to an adequate food supply.

# %%
Group22.__gapminder__(agros_data, 1980,1.2)
Group22.__gapminder__(agros_data, 2019,1.2)

# %% [markdown]
# ## A story about agricultural evolution
#
# ### Chosen countries: China, Italy, Germany
#
# ### Analysis:
#
# Germany, Italy, and China have different histories when it comes to agricultural output, which is also reflected in the follwing graphs below. In Germany, the agricultural sector has traditionally been focused on animal farming and crop production. German farmers have been known for their high-quality animal products and the country has been exporting dairy and meat products to other European countries. Although there have been some fluctuations in output due to weather conditions and diseases in the past, overall the agricultural output has remained relatively stable. Germany is now focusing on sustainable agriculture, looking for ways to produce food while also taking care of the environment.
#
# On the other hand, Italy's agricultural output has been more plant-based. Italy is known for its olive oil, wine, and pasta, which are all heavily dependent on crop production. Farmers in Italy have also been growing olives for thousands of years and the country is the world's second-largest producer of olive oil. However, in recent years, there has been a decline in agricultural output in Italy due to factors such as urbanization and climate change. Many young people in Italy are not interested in working in the agricultural sector, leading to a shortage of workers and a decline in output.
#
# In contrast, China's agricultural output has experienced a significant boom over the past few decades. In 1960, China's total agricultural output was only twice that of Germany, but since then it has grown exponentially due to a combination of factors. China has the largest population in the world, making food production a top priority for the government. Investments in technology and infrastructure have also led to increased productivity. In addition to traditional crops such as rice and wheat, China is now also a major producer of fruits and vegetables. Although the country is facing challenges such as water scarcity and air pollution, China is still expected to be a major player in the global food market in the coming years.
#
# Despite their differences, all three countries have seen an increase in agricultural productivity over time. Looking at the bigger picture, the world as a whole has also become more productive in producing food, as seen in the evolution of TFP values from 2000 to 2019. As the global population continues to grow, it will be important to continue finding sustainable ways to produce food and to ensure that everyone has access to enough nutritious food.

# %%
Group22.plot_output_area_chart(agros_data, country='China')

# %%
Group22.plot_output_area_chart(agros_data, country='Italy')

# %%
Group22.plot_output_area_chart(agros_data, country='Germany')

# %%
Group22.compare_output_countries(agros_data, ['China', 'Italy', 'Germany'])

# %% [markdown]
# ## **Choropleth** for 2000 and 2019
#
# ### Analysis:
#
# Between 2000 and 2019, there was an overall increase in agricultural productivity worldwide. The choropleth maps of the world below representing the agricultural yield per country show this evolution. In 2000, the minimum TFP value was 44 and the maximum was 254, with a mean of 89 and a median of 84. In 2019, the minimum TFP value was 65 and the maximum was 169, with a mean of 104 and a median of 102. This represents an anual increase of about 1.2% for the mean TFP value. This increase in agricultural productivity can be attributed to a combination of factors such as technological advancements, improved farming practices, and better access to markets and information.

# %%
Group22.choropleth(agros_data, 2000,0,250)
Group22.choropleth(agros_data, 2019,0,250)
# Out:
# TFP values
# Max: 254
# Min: 44
# Mean:  89
# Median: 84
# TFP values
# Max: 169
# Min: 65
# Mean:  104
# Median: 102

# %% [markdown]
# ## Predictions of total factor productivity (TFP)
#
# ### Analysis:
# According to the predictions from the graph below, it seems that the growth of TFP in Italy and Germany is going to be moderate in the future. On the other hand, China is expected to experience a heavier increase in TFP, which could be indicative of its ongoing efforts to modernize its agricultural sector. This trend is in line with the significant increase in agricultural yield that China has experienced since the 1980s, where its agricultural production has increased by more than three times. This growth is particularly notable given the size of China's agricultural sector and has contributed significantly to the overall growth of agricultural production in the world.

# %%
Group22.predictor(agros_data, ['China', 'Italy', 'Germany'])
